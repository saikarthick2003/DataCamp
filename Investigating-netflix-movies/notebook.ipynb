# %% [markdown]
# ![Movie popcorn on red background](redpopcorn.jpg)

# %% [markdown]
# **Netflix**! What started in 1997 as a DVD rental service has since exploded into one of the largest entertainment and media companies.
#
# Given the large number of movies and series available on the platform, it is a perfect opportunity to flex your exploratory data analysis skills and dive into the entertainment industry. Our friend has also been brushing up on their Python skills and has taken a first crack at a CSV file containing Netflix data. They believe that the average duration of movies has been declining. Using your friends initial research, you'll delve into the Netflix data to see if you can determine whether movie lengths are actually getting shorter and explain some of the contributing factors, if any.
#
# You have been supplied with the dataset `netflix_data.csv` , along with the following table detailing the column names and descriptions. This data does contain null values and some outliers, but handling these is out of scope for the project. Feel free to experiment after submitting!
#
# ## The data
# ### **netflix_data.csv**
# | Column | Description |
# |--------|-------------|
# | `show_id` | The ID of the show |
# | `type` | Type of show |
# | `title` | Title of the show |
# | `director` | Director of the show |
# | `cast` | Cast of the show |
# | `country` | Country of origin |
# | `date_added` | Date added to Netflix |
# | `release_year` | Year of Netflix release |
# | `duration` | Duration of the show in minutes |
# | `description` | Description of the show |
# | `genre` | Show genre |

# %%
# Importing pandas and matplotlib
import pandas as pd
import matplotlib.pyplot as plt

# Start coding!
netflix_df = pd.read_csv("netflix_data.csv")
netflix_df.head(5)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 3
#       1 # Importing pandas and matplotlib
#       2 import pandas as pd
# ----> 3 import matplotlib.pyplot as plt
#       5 # Start coding!
#       6 netflix_df = pd.read_csv("netflix_data.csv")
#
# ModuleNotFoundError: No module named 'matplotlib'

# %%
netflix_subset= netflix_df[netflix_df["type"] == "Movie"]
netflix_subset.head(5)
# Out:
#   show_id  ...          genre
# 1      s2  ...         Dramas
# 2      s3  ...  Horror Movies
# 3      s4  ...         Action
# 4      s5  ...         Dramas
# 6      s7  ...  Horror Movies
#
# [5 rows x 11 columns]

# %%
netflix_movies = netflix_subset[["title","country","genre","release_year","duration"]]
netflix_movies.head(10)
# Out:
#     title        country          genre  release_year  duration
# 1    7:19         Mexico         Dramas          2016        93
# 2   23:59      Singapore  Horror Movies          2011        78
# 3       9  United States         Action          2009        80
# 4      21  United States         Dramas          2008       123
# 6     122          Egypt  Horror Movies          2019        95
# 7     187  United States         Dramas          1997       119
# 8     706          India  Horror Movies          2019       118
# 9    1920          India  Horror Movies          2008       143
# 10   1922  United States         Dramas          2017       103
# 13  2,215       Thailand  Documentaries          2018        89

# %%
short_movies = netflix_movies[netflix_movies["duration"]< 60]
short_movies.head(20)
# Out:
#                                                  title  ... duration
# 35                                           #Rucker50  ...       56
# 55                 100 Things to do Before High School  ...       44
# 67   13TH: A Conversation with Oprah Winfrey & Ava ...  ...       37
# 101                                  3 Seconds Divorce  ...       53
# 146                                     A 3 Minute Hug  ...       28
# 162  A Christmas Special: Miraculous: Tales of Lady...  ...       22
# 171                         A Family Reunion Christmas  ...       29
# 177                    A Go! Go! Cory Carson Christmas  ...       22
# 178                    A Go! Go! Cory Carson Halloween  ...       22
# 179                  A Go! Go! Cory Carson Summer Camp  ...       21
# 181             A Grand Night In: The Story of Aardman  ...       59
# 200                            A Love Song for Latasha  ...       20
# 220                         A Russell Peters Christmas  ...       44
# 233                              A StoryBots Christmas  ...       26
# 237                             A Tale of Two Kitchens  ...       30
# 242                            A Trash Truck Christmas  ...       28
# 247                            A Very Murray Christmas  ...       57
# 285                               Abominable Christmas  ...       44
# 295                                 Across Grace Alley  ...       24
# 305                Adam Devine: Best Time of Our Lives  ...       59
#
# [20 rows x 5 columns]

# %%
colors = []
for lab,row in netflix_movies.iterrows():
    if row["genre"] == "Children":
        colors.append("cyan")
    elif row["genre"] == "Documentaries":
        colors.append("red")
    elif row["genre"] == "Stand-Up":
        colors.append("green")
    elif row["genre"] == "Dramas":
        colors.append("blue")
    else:
        colors.append("black")

# %%
colors[:10]
print(colors)
# Out:
# ['blue', 'black', 'black', 'blue', 'black', 'blue', 'black', 'black', 'blue', 'red', 'black', 'blue', 'blue', 'black', 'black', 'blue', 'black', 'blue', 'blue', 'red', 'black', 'red', 'red', 'blue', 'blue', 'black', 'black', 'red', 'black', 'black', 'black', 'black', 'black', 'black', 'blue', 'black', 'blue', 'blue', 'black', 'black', 'black', 'red', 'blue', 'black', 'red', 'blue', 'blue', 'blue', 'black', 'black', 'red', 'black', 'black', 'black', 'red', 'black', 'black', 'blue', 'blue', 'black', 'black', 'black', 'black', 'red', 'black', 'black', 'blue', 'black', 'black', 'black', 'black', 'blue', 'black', 'red', 'black', 'black', 'blue', 'blue', 'blue', 'black', 'red', 'black', 'black', 'black', 'blue', 'blue', 'blue', 'black', 'red', 'cyan', 'black', 'black', 'blue', 'black', 'black', 'black', 'black', 'black', 'black', 'blue', 'black', 'blue', 'black', 'black', 'blue', 'black', 'black', 'blue', 'black', 'blue', 'black', 'blue', 'cyan', 'red', 'cyan', 'black', 'blue', 'blue', 'blue', 'black', 'black', 'cyan', 'black', 'black', 'blue', 'cyan', 'cyan', 'cyan', 'black', 'cyan', 'cyan', 'black', 'blue', 'cyan', 'blue', 'red', 'blue', 'black', 'black', 'blue', 'black', 'blue', 'black', 'cyan', 'cyan', 'cyan', 'red', 'red', 'black', 'black', 'blue', 'cyan', 'black', 'red', 'black', 'blue', 'red', 'red', 'blue', 'red', 'blue', 'black', 'black', 'blue', 'blue', 'red', 'red', 'blue', 'black', 'blue', 'blue', 'blue', 'blue', 'red', 'cyan', 'black', 'green', 'black', 'blue', 'red', 'blue', 'black', 'cyan', 'black', 'blue', 'blue', 'blue', 'blue', 'cyan', 'blue', 'blue', 'red', 'black', 'black', 'cyan', 'black', 'cyan', 'blue', 'black', 'black', 'black', 'blue', 'black', 'red', 'black', 'cyan', 'cyan', 'blue', 'black', 'black', 'blue', 'black', 'black', 'black', 'black', 'blue', 'black', 'blue', 'blue', 'blue', 'blue', 'black', 'black', 'black', 'blue', 'blue', 'black', 'red', 'blue', 'black', 'cyan', 'black', 'black', 'blue', 'black', 'black', 'blue', 'blue', 'blue', 'black', 'black', 'cyan', 'black', 'black', 'blue', 'green', 'green', 'blue', 'black', 'green', 'black', 'green', 'blue', 'black', 'black', 'blue', 'black', 'black', 'green', 'blue', 'red', 'red', 'red', 'red', 'blue', 'blue', 'blue', 'black', 'blue', 'black', 'blue', 'green', 'black', 'blue', 'red', 'blue', 'black', 'blue', 'black', 'black', 'black', 'black', 'blue', 'black', 'black', 'black', 'black', 'green', 'black', 'blue', 'blue', 'cyan', 'green', 'red', 'black', 'green', 'black', 'black', 'black', 'red', 'blue', 'black', 'green', 'green', 'black', 'red', 'black', 'black', 'black', 'red', 'black', 'cyan', 'cyan', 'red', 'blue', 'black', 'black', 'blue', 'cyan', 'black', 'cyan', 'red', 'black', 'black', 'black', 'blue', 'black', 'black', 'black', 'blue', 'black', 'blue', 'blue', 'black', 'blue', 'blue', 'black', 'cyan', 'cyan', 'red', 'red', 'black', 'black', 'black', 'red', 'red', 'blue', 'black', 'black', 'blue', 'blue', 'red', 'red', 'black', 'blue', 'red', 'red', 'red', 'red', 'red', 'black', 'black', 'blue', 'blue', 'red', 'red', 'black', 'black', 'blue', 'blue', 'green', 'black', 'blue', 'red', 'green', 'green', 'red', 'cyan', 'cyan', 'cyan', 'cyan', 'black', 'black', 'black', 'blue', 'blue', 'blue', 'blue', 'black', 'black', 'black', 'black', 'blue', 'black', 'blue', 'blue', 'black', 'black', 'black', 'black', 'black', 'red', 'red', 'blue', 'black', 'blue', 'black', 'cyan', 'cyan', 'black', 'black', 'blue', 'black', 'blue', 'blue', 'cyan', 'black', 'black', 'black', 'green', 'blue', 'blue', 'cyan', 'blue', 'blue', 'black', 'black', 'cyan', 'green', 'green', 'black', 'black', 'red', 'blue', 'red', 'blue', 'red', 'black', 'black', 'black', 'black', 'blue', 'green', 'cyan', 'blue', 'black', 'green', 'red', 'black', 'black', 'black', 'green', 'black', 'cyan', 'blue', 'blue', 'black', 'black', 'blue', 'blue', 'black', 'red', 'black', 'black', 'black', 'blue', 'black', 'red', 'blue', 'red', 'blue', 'blue', 'black', 'red', 'black', 'red', 'blue', 'red', 'black', 'bl ...

# %%
colors_corrected = ['blue' if color == 'greem' else color for color in colors]

fig = plt.figure(figsize=(12,8))
plt.scatter(netflix_movies.release_year, netflix_movies.duration, c=colors_corrected)
plt.title("Movie Duration by Year of Release")
plt.xlabel("Release year")
plt.ylabel("Duration (min)")
plt.show()

# %%
answer = "no"
